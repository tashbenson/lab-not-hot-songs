# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('data.csv')

df.head()
# Out:
#    Unnamed: 0  acousticness  danceability  duration_ms  energy  \
# 0           0        0.0102         0.833       204600   0.434
# 1           1        0.1990         0.743       326933   0.359
# 2           2        0.0344         0.838       185707   0.412
# 3           3        0.6040         0.494       199413   0.338
# 4           4        0.1800         0.678       392893   0.561
#
#    instrumentalness  key  liveness  loudness  mode  speechiness    tempo  \
# 0          0.021900    2    0.1650    -8.795     1       0.4310  150.062
# 1          0.006110    1    0.1370   -10.401     1       0.0794  160.083
# 2          0.000234    2    0.1590    -7.148     1       0.2890   75.044
# 3          0.510000    5    0.0922   -15.236     1       0.0261   86.468
# 4          0.512000    5    0.4390   -11.648     0       0.0694  174.004
#
#    time_signature  valence  target      song_title            artist
# 0             4.0    0.286       1        Mask Off            Future
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'acousticness', 'danceability', 'duration_ms', 'energy',
#        'instrumentalness', 'key', 'liveness', 'loudness', 'mode',
#        'speechiness', 'tempo', 'time_signature', 'valence', 'target',
#        'song_title', 'artist'],
#       dtype='object')

# %%
df.drop(['Unnamed: 0', 'acousticness', 'danceability', 'duration_ms', 'energy',
       'instrumentalness', 'key', 'liveness', 'loudness', 'mode',
       'speechiness', 'tempo', 'time_signature', 'valence', 'target',], axis=1, inplace=True)

# %%
df.head()
# Out:
#        song_title            artist
# 0        Mask Off            Future
# 1         Redbone  Childish Gambino
# 2    Xanny Family            Future
# 3  Master Of None       Beach House
# 4  Parallel Lines       Junior Boys

# %%
df.rename(columns={'song_title': 'title'}, inplace=True)

# %%
df.head()
# Out:
#             title            artist
# 0        Mask Off            Future
# 1         Redbone  Childish Gambino
# 2    Xanny Family            Future
# 3  Master Of None       Beach House
# 4  Parallel Lines       Junior Boys

# %%
hot_100 = pd.read_csv("hot_100.csv")
hot_100
# Out:
#                           title                                artist
# 0                       Flowers                           Miley Cyrus
# 1                     Kill Bill                                   SZA
# 2                      Creepin'  Metro Boomin, The Weeknd & 21 Savage
# 3                     Anti-Hero                          Taylor Swift
# 4                        Unholy                Sam Smith & Kim Petras
# ..                          ...                                   ...
# 95                      Hey Mor                  Ozuna Featuring Feid
# 96                Gato de Noche                Nengo Flow & Bad Bunny
# 97               Heart To Heart                           Mac DeMarco
# 98  Never Gonna Not Dance Again                                  P!nk
# 99       Dancin' In The Country                         Tyler Hubbard
#
# [100 rows x 2 columns]

# %%
data = pd.concat([hot_100, df], axis=0)
data
# Out:
#                                      title  \
# 0                                  Flowers
# 1                                Kill Bill
# 2                                 Creepin'
# 3                                Anti-Hero
# 4                                   Unholy
# ...                                    ...
# 2012   Like A Bitch - Kill The Noise Remix
# 2013                                 Candy
# 2014  Habit - Dack Janiels & Wenzday Remix
# 2015                         First Contact
# 2016                    I Wanna Get Better
#
#                                     artist
# 0                              Miley Cyrus
# 1                                      SZA
# 2     Metro Boomin, The Weeknd & 21 Savage
# 3                             Taylor Swift
# 4                   Sam Smith & Kim Petras
# ...                                    ...
# 2012                        Kill The Noise
# 2013                        Dillon Francis
# 2014                              Rain Man
# ...

# %%
data= data.drop_duplicates()
data
# Out:
#                                      title  \
# 0                                  Flowers
# 1                                Kill Bill
# 2                                 Creepin'
# 3                                Anti-Hero
# 4                                   Unholy
# ...                                    ...
# 2012   Like A Bitch - Kill The Noise Remix
# 2013                                 Candy
# 2014  Habit - Dack Janiels & Wenzday Remix
# 2015                         First Contact
# 2016                    I Wanna Get Better
#
#                                     artist
# 0                              Miley Cyrus
# 1                                      SZA
# 2     Metro Boomin, The Weeknd & 21 Savage
# 3                             Taylor Swift
# 4                   Sam Smith & Kim Petras
# ...                                    ...
# 2012                        Kill The Noise
# 2013                        Dillon Francis
# 2014                              Rain Man
# ...
